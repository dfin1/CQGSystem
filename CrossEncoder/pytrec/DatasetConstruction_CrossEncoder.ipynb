# %%
import json
import pandas as pd
import requests
import random

# %%
#Param
FascetRepetitionFactor = 1

# %%
#Get Any Randomn Fascet
def getRndFascet():
    leng = len(df)
    rnd = int(random.random()*leng)
    
    fascetsArr = df.iloc[rnd]['fascets_5'].split(' , ')
    fascet = fascetsArr[int(random.random()*len(fascetsArr))]
    
    return fascet
    
#Check if that Fascet is no a true one
def selectRndFascet(trueFascets):
    fascet = getRndFascet()
    while fascet in trueFascets:
        fascet = getRndFascet()
        
    return fascet

# %% [markdown]
# ## Dataframe construction:

# %%
df = pd.read_csv('../../Data/DF_MIMICS_ConstructedFascets_v2_6.csv')

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0                          query  \
# 0                 0           0                       rimouski
# 1                 1           1                            ohe
# 2                 2           2    ballet folklorico de mexico
# 3                 3           3                           ubac
# 4                 4           4                   book of ezra
# ...             ...         ...                            ...
# 19046         19046       19046  karnataka legislative council
# 19047         19047       19047                           bsps
# 19048         19048       19048                  canon pro-100
# 19049         19049       19049                         rv max
# 19050         19050       19050                           eapw
#
#                                                  fascets  \
# 0        climate , economy , municipal council , history
# 1      office of higher education , office of health ...
# ...

# %%
df_tmp = []
for idx, item in df.iterrows():
    trueFascets = item['fascets'].split(' , ')
    #Add True Fascets 
    for fascet in trueFascets:
        for i in range(FascetRepetitionFactor):
            el = {
                'query' : item['query'],
                'clariQ' : item['target'],  
                'fascet' : fascet,
                'isRelated' : 1
            }
            df_tmp.append(el)
    
    #Add False Fascets
    print("false Fascets")
    fascetsArr = item['fascets_20'].split(' , ')
    for idx, fascet in enumerate(fascetsArr):
        for i in range(FascetRepetitionFactor):
            el = {
                'query' : item['query'],
                'clariQ' : item['target'],  
                'fascet' : fascet,
                'isRelated' : 0
            }
            df_tmp.append(el)
df_full = pd.DataFrame(df_tmp)
# Out:
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# false Fascets
# ...

# %%
df_full = df_full.sample(frac=1)

# %%
df_full
# Out:
#                           query  \
# 163793      gmail email address
# 162361                     swmp
# 49952   brotherhood of the wolf
# 249336                self less
# 234910                     cstc
# ...                         ...
# 51810           the pizza place
# 226018  letcher county kentucky
# 139003                 ford ka+
# 289701     sterling connecticut
# 119111                     wcet
#
#                                                   clariQ  \
# 163793  What do you want to do with gmail email address?
# 162361                         Which "swmp" do you mean?
# 49952           What do you want to know about the film?
# 249336          What do you want to know about the film?
# 234910                         Which "cstc" do you mean?
# ...                                                  ...
# 51810    What do you want to know about this restaurant?
# 226018     What would you like to know about this place?
# ...

# %%
df_full.to_csv("../../Data/DF_Constructed_CrossEncoder_dataset.csv")
